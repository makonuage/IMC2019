# %% [markdown]
# <br />
# <br />
# <br />
# # 機械知能計測研究室2019
# <br />
# <br />
# <br />

# %% [markdown]
# ## やること
#
# - 部屋・席決め
# - 研究室についての説明(軽い復習)
# - 研究室のグループLINEについて
# - 係決め
# - 当分の予定について
# - 連絡事項

# %% [markdown]
# ## 研究室について
#
# 小西先生・荒木先生・佐藤先生の学生で構成されています.
# ![fig.png](attachment:fig.png)

# %% [markdown]
# ## 研究室について
#
#  ### コアタイムについて
#
#  - コアタイムは<u>10:30 ~ 18:00</u>です
#  - この時間には研究室にいましょう.
#  - 欠席・早退・遅刻は<u>自分の状況に合わせて</u>適宜とってください.(連絡は欲しい)
#  - 就活・院試勉強について特に制限はありません.頑張ってください.

# %% [markdown]
#  ## 輪講・報告会について
#
#  - 研究室では毎週報告会(前期・後期)と輪講(前期のみ)を行います.
#  - 時間についてはM1が調整するので授業等の関係で参加できない時間を伝えてください.
#  - 詳細説明は後日行います(多分M1がやる)
#
#  #### <メモ>

# %% [markdown]
# ## 当分の予定
#
#  - 4/1 ~ 4/12の間にプログラミング教室を実施します.
#  - 輪講の資料を配布するので自分の担当箇所の翻訳・学習を行ってください.
#  - 研究の進め方は指導教員によって違います.
#  - きになる人は先生に凸するか,院生に聞いてみてください.
#
# #### <u>細々したことは雰囲気で分かるのでとにかく研究室にいてください.</u>

# %% [markdown]
# ## 年間予定
# ざっくりこんなかんじです.
# ![%E4%BA%88%E5%AE%9A.png](attachment:%E4%BA%88%E5%AE%9A.png)

# %% [markdown]
# ## 連絡事項
#
#  - 4/5(金)に米パします．よかったら参加してください
#  - 4/19(金)の18:00~研究室新歓を行います(途中参加OK)(参加推奨).
#  - この後13:00~M2のポスター発表があるのでひやかしに来てください.

# %% [markdown]
# ## 係決め(これ部屋ごとや...)
#
#  部屋の係があります(適当)
#  - 買い出し(1)
#  - 会計(1)
#  - 掃除(1)
#  - お茶(1)
#  - 水回り(1)
#  - ゴミ捨て(2)
